# %% [markdown]
# # ryder_pattern_1

# %%
import camelot

tables = camelot.read_pdf(r'C:\Users\majidmm\Documents\AMXL\INPUT_FILES\format_1.pdf',pages='1,2')
# tables_1 = camelot.read_pdf(r'C:\Users\majidmm\Documents\AMXL\INPUT_FILES\format_1.pdf',pages='2',flavor='lattice')# tables[0].df
a=tables[1].df
a
# b=tables[0].df
# b

# mileage_rate = a.iloc[17,1]
# mileage_rate.lower()
# Rental_Date = a[0][10]
# mileage_units=a.iloc[17, 2]
# print(mileage_units)

# pick_date = a.iloc[14, 4]
# print(pick_date.strip('Pick Date/Time'))

# return_date = a.iloc[15, 4]
# print(return_date.strip('Return Date/Time'))

# vehicle_number = a.iloc[25, 5]
# print(vehicle_number)

# vehicle_number_2 = a.iloc[25, 4].strip()
# print(vehicle_number_2.strip('Vehicle Number'))

# tax_rate = b.iloc[2,1].strip('$')
# tax_rate=float(tax_rate)
# print(tax_rate)

# # tables.export(r'C:\Users\majidmm\Documents\MTI and RC\RC\INPUT FILES\abc.csv', f='csv')
# Out:
#                   0      1 2        3                                      4  \
# 0  Misc. Deductions  $0.00      $0.00                      Outbound Odometer
# 1        Misc. Fees                                         Inbound Odometer
# 2         Sales Tax  $0.00      $0.00  Client Purchase Order\n(If Submitted)
# 3   Invoice Total :           $542.10        Employee who picked\nup rental:
#
#                     5
# 0               91693
# 1               95236
# 2                  NA
# 3  Reginald Brown Jr.

# %% [markdown]
# # ryder_pattern_2

# %%
import camelot

tables = camelot.read_pdf(r'C:\Users\majidmm\Documents\AMXL\NOTES\format_2.pdf',pages='3',flavor='stream',split_text= True,edge_tol=500)
# tables[0].df
a=tables[0].df
a

vehicle_number = a.iloc[6, 2]
print(vehicle_number)

pick_date = a.iloc[10, 2]
print(pick_date.strip('Pick Date/Time'))

return_date = a.iloc[11, 2]
print(return_date.strip('Return Date/Time'))

mileage_units=a.iloc[20, 2]
print(mileage_units)

period_billed = a.iloc[13, 2]
print(period_billed)

# tables.export(r'C:\Users\majidmm\Documents\MTI and RC\RC\INPUT FILES\abc.csv', f='csv')
# Out:
# 246194
# 01/13/20, 14:43
# 02/09/20, 06:59
# 4297
# 02/03/20-02/09/20

# %% [markdown]
# # ryder_pattern_3

# %%
from PIL import Image
import cv2 
import pytesseract
import re 
from pytesseract import Output
import numpy as np

tesseract_exe_path_installation="C:\\Users\\majidmm\\AppData\\Local\\Tesseract-OCR\\tesseract.exe"
pytesseract.pytesseract.tesseract_cmd=tesseract_exe_path_installation

img = cv2.imread(r'C:\Users\majidmm\Documents\AMXL\OUTPUT_FILES\files_dump_all_patterns\pattern_3\870230.png')


custom_config = r'--psm 6' 

text = pytesseract.image_to_string(img,output_type=Output.STRING,config=custom_config)

t=text.lower()

print(t)

left = 'hicle no:'
right = 'customer information'
vehicle_number = t[t.index(left)+len(left):t.index(right)]
vehicle_number.strip()
print(vehicle_number[0:7].strip())

      
left = 'out:'
right = 'used:'
pick_date = t[t.index(left)+len(left):t.index(right)]
print(pick_date[0:10].strip())
            
left = 'in:'
right = 'st:'
return_date = t[t.index(left)+len(left):t.index(right)]
print(return_date[0:10].strip())
            

left = 'mileage rate'
right = '/m ='
mileage_rate = t[t.index(left)+len(left):t.index(right)]
print(mileage_rate[-6:])

left = 'mileage rate'
right = 'miles'
mileage = t[t.index(left)+len(left):t.index(right)]
print(mileage.strip())

left = 'sales tax'
right = 'special tax'
sales_tax = t[t.index(left)+len(left):t.index(right)]
print(sales_tax[-6:].strip())

left = 'special tax =s'
right = '** special rate'
special_tax = t[t.index(left)+len(left):t.index(right)]
print(special_tax.strip())

# left = '1 week'
# right = '** special rate'
# # week_tax = t[t.index(left)+len(left):t.index(right)]
# # print(week_tax[-5:0].strip())
# try:
#     week_tax = t[t.index(left)+len(left):t.index(right)]
#     print(week_tax[-5:0].strip())
# except ValueError:
#     print(0)
    
# week_tax = t[t.index(left)+len(left):t.index(right)]
# print(week_tax[-5:0].strip())
# Out:
# © ryder’ customer reference number: 0765000301015
# rental agreement number _— : 689989 client account number: 286448
# rental location/contact information hours of operation and additional information
# ryder truck rental, inc. mon — fri: 7:00 am-5:00 pm ss
# 400 south mac arthur saturday : closed ly news
# oklahoma city, oklahoma, 73128 sunday: closed $ pyoes, %
# phone number: 4059477626 24/7 roadside assistance: 866-477-0438 mental
# sales rep - ixunderw customer service : 1-800-947-9337 > lp
# tisf
# area manager : ty wheeler -
# ty_a_wheeler@ryder.com
# kkekkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkekkekkkkkekkkkkkkehek t n v o t cc eb
# ** with fuel fuel 18 ** activity date : 06/22/20
# ** *x  cust ref #: 0765000301015
# ** **x vehicle no: 870230
# customer information driver information date/time/mileage info:
# tecara logitics llc richard ivn luht due: 06/22/20 07:00
# 4217 stirrup ln d.o.b.: **/**/**
# edmond, ok per #aaaaaaaaty6 in: 06/22/20 07:00
# ...

# %% [markdown]
# # format_4

# %%
import camelot

tables = camelot.read_pdf(r'C:\Users\majidmm\Documents\AMXL\INPUT_FILES\format_4.pdf',pages='1',flavor='stream')
# tables[0].df
a=tables[0].df
a


vehicle_number = a.iloc[1, 1]
print(vehicle_number)

pick_date = a.iloc[6, 1]
print(pick_date.strip('Pick Date/Time'))

return_date = a.iloc[7, 1]
print(return_date.strip('Return Date/Time'))

mileage_units=a.iloc[10, 1]
print(mileage_units)

mileage_rate = a.iloc[8, 5]
print(mileage_rate.strip('$'))
# Out:
# 264251
# 09/15/2018
# 09/22/2018
# 800
# 0.15

# %% [markdown]
# # format_5

# %%
import camelot

tables = camelot.read_pdf(r'C:\Users\majidmm\Documents\AMXL\INPUT_FILES\format_5.pdf',pages='1',flavor='stream')
# tables[0].df
a=tables[0].df
a

# vehicle_number = a.iloc[9, 3]
# print(vehicle_number)

# pick_date_1 = a.iloc[4, 1]
# pick_date_2 = a.iloc[4, 2]
# pick_date = pick_date_1+' '+pick_date_2
# print(pick_date.strip())

# return_date_1= a.iloc[]
# return_date_2= a.iloc[]
# return_date = return_date_1+' '+return_date_2
# print(return_date.strip())

# mileage_units=a.iloc[10, 0]
# print(mileage_units)

# mileage_rate = a.iloc[8, 5]
# print(mileage_rate.strip('$'))
# Out:
#                                  0  \
# 0   9:02:41 Tuesday, April 7, 2020
# 1                         RN210S40
# 2                        Location:
# 3                       Cust.Ref#:
# 4                        Pick-up.:
# 5                   Period..:\n01W
# 6                       Due\nIn..:
# 7
# 8
# 9                           1\n16'
# 10                             645
# 11                         $0\nDED
# 12                       PHYS\nDMG
# 13                      GD\nWaiver
# 14                    TX\nSales\n&
# 15                        Contract
#
#                                                     1             2  \
# 0
# 1                                                3004
# 2                                                0789  RTR-N.AUSTIN
# 3                                      7606-0045-0999
# 4                                             3/26/20          7:09
# 5                                                              Rate
# ...

# %% [markdown]
# # pdf to  image converter

# %%
#     path = r'C:\Users\majidmm\Documents\AMXL\INPUT_FILES\dump\FEB_24_TO_MAR_05_____972.16_1_.pdf'


#PDF TO IMAGE CONVERSION
#IMPORT LIBRARIES
import pdf2image
from PIL import Image
import os

#DECLARE CONSTANTS
PDF_PATH = r'C:\Users\majidmm\Documents\AMXL\INPUT_FILES\dump\MAR_02_TO__MAR_07_____493.52_1_.pdf'
DPI = 500
OUTPUT_FOLDER = r'C:\Users\majidmm\Documents\AMXL\INPUT_FILES\dump\\'
FIRST_PAGE = 1
LAST_PAGE = 1
FORMAT = 'png'
THREAD_COUNT = 1
USERPWD = None
USE_CROPBOX = False
STRICT = False

    #This method reads a pdf and converts it into a sequence of images
    #PDF_PATH sets the path to the PDF file
    #dpi parameter assists in adjusting the resolution of the image
    #output_folder parameter sets the path to the folder to which the PIL images can be stored (optional)
    #first_page parameter allows you to set a first page to be processed by pdftoppm 
    #last_page parameter allows you to set a last page to be processed by pdftoppm
    #fmt parameter allows to set the format of pdftoppm conversion (PpmImageFile, TIFF)
    #thread_count parameter allows you to set how many thread will be used for conversion.
    #userpw parameter allows you to set a password to unlock the converted PDF
    #use_cropbox parameter allows you to use the crop box instead of the media box when converting
    #strict parameter allows you to catch pdftoppm syntax error with a custom type PDFSyntaxError

pil_images = pdf2image.convert_from_path(PDF_PATH, dpi=DPI, output_folder=OUTPUT_FOLDER, first_page=FIRST_PAGE, last_page=LAST_PAGE, fmt=FORMAT, thread_count=THREAD_COUNT, userpw=USERPWD, use_cropbox=USE_CROPBOX, strict=STRICT)
for image in pil_images:
    image.save("page"  + ".png")

# %%
from PIL import Image
import cv2 
import pytesseract
import re 
from pytesseract import Output
import pandas as pd

tesseract_exe_path_installation="C:\\Users\\majidmm\\AppData\\Local\\Tesseract-OCR\\tesseract.exe"
pytesseract.pytesseract.tesseract_cmd=tesseract_exe_path_installation

img = cv2.imread(r'C:\Users\majidmm\Documents\AMXL\OUTPUT_FILES\files_dump_p1,2,3\images_all\FIC___R5_2_11_20_to_2_16_20_5dys_776972_Receipt.jpg')

custom_config = r'--oem 3 --psm 6'

f=[]
x=[]
t=[]

text = pytesseract.image_to_string(img,config=custom_config,output_type=Output.STRING)
text
# f.append(img)
# t.append(text)

# x.append('customer reference number' in text.lower())


# df = pd.DataFrame(list(zip( f,t,x)),columns=['file_Name','full_text','pattern_1'])

# pattern_1=df[df['pattern_1']== True]

# pattern_1['file_Name'].to_csv(r"C:\Users\majidmm\Documents\AMXL\OUTPUT_FILES\files_dump_p1,2,3\z1\p1.csv",index=False, header=False)

# df
# left = 'VEHICLE NO:'
# right = 'CUSTOMER INFORMATION'

# vehicle_number = t[t.index(left)+len(left):t.index(right)]
# print(vehicle_number)

# left = 'OUT:'
# right = 'USED:'

# pick_date = t[t.index(left)+len(left):t.index(right)]
# print(pick_date[0:15])

# left = 'IN:'
# right = 'ST:'

# return_date = t[t.index(left)+len(left):t.index(right)]
# print(return_date[0:15])


# left = 'Mileage Rate'
# right = 'Miles'

# mileage = t[t.index(left)+len(left):t.index(right)]
# print(mileage)
# Out:
# "(Myder’ = cusToMER REFERENCE NUMBER: 0760600448126\nRENTAL AGREEMENT NUMBER _— : 904334 CLIENT ACCOUNT NUMBER: 280229\nRental Location/Contact Information Hours of Operation and additional information\nRyder Truck Rental, Inc. Mon — Fri: 7:00 AM-4:30 PM —,\n8305 NORTH LAMAR Saturday : 8:00 AM-10:00 AM Lye <r\nAUSTIN, TEXAS, 78753 Sunday: Closed $ nycer, .\nPhone Number: 5128367184 24/7 Roadside Assistance: 366-477-0438 acl\nSales Rep : MXTYLER Customer Service : 1-800-947-9337 or yy\nTISF\nArea Manager : Morgan Johnson ~\nMorgan_Johnson@ryder.com\nKKK KKEKKEKEKKKRKEKKEK KKK KEK KKK KKK KKK KKK KKK KKEKEKKEKKKKEKEKKEKEKKKEEKE I N V O I Cc EB\n+ WITH FUEL FUEL 17 ** ACTIVITY DATE : 02/28/20\nae **  CUST REF #: 0760600448126\nee ** VEHICLE NO: 776972\nCUSTOMER INFORMATION DRIVER INFORMATION DATE/TIME/MILEAGE INFO:\nFIRST IN CARGO ~—«<dJeffery E Cormican. ——s DUE: 02/25/20 07:00\n5811 TRADE CENTER DR BLDG D.O.B.: **/**/**\nG 10 Per #AAAAAAAA1DO IN: 02/16/20 07:00\nAUSTIN, TX ST: TX EXP.
# ...

# %%
import os
import tempfile
from pdf2image import convert_from_path

input_dir=r'C:\Users\majidmm\Documents\AMXL\INPUT_FILES\all_input_files\\'
for root, dirs, filenames in os.walk(input_dir):
    for filename in filenames:
        with tempfile.TemporaryDirectory() as path:
            pdf_path=input_dir+filename
            images_from_path = convert_from_path(pdf_path, output_folder=path, last_page=1, first_page =1,dpi=400,thread_count=1)
            base_filename  =  os.path.splitext(os.path.basename(filename))[0] + '.jpg'     
            save_dir = r'C:\Users\majidmm\Documents\AMXL\OUTPUT_FILES\files_dump_p1,2,3\images_all\\'
            for page in images_from_path:
                page.save(os.path.join(save_dir, base_filename), 'JPEG')
                print(filename)
# Out:
# 13909669_Rental_Communication.pdf
# 13914181_Rental_Communication___Invoice.pdf
# 13914387_Rental_Communication___Invoice.pdf
# 13914708_Rental_Communication___Invoice.pdf
# 13914840_Rental_Communication___Invoice.pdf
# 13914842_Rental_Communication___Invoice.pdf
# 13915191_Rental_Communication___Invoice.pdf
# 13915193_Rental_Communication___Invoice.pdf
# 13915195_Rental_Communication___Invoice.pdf
# 13915485_Rental_Communication___Invoice.pdf
# 13915487_Rental_Communication___Invoice.pdf
# 13916242_Rental_Communication.pdf
# 13917738_Rental_Communication.pdf
# 13917881_Rental_Communication.pdf
# 13917888_Rental_Communication.pdf
# 13917892_Rental_Communication.pdf
# 13917896_Rental_Communication.pdf
# 13919743_Rental_Communication___invoice.pdf
# 2020_02_27_248053_662_miles.pdf
# 2020_02_27_810405_1497_miles.pdf
# 2020_02_28_643568_1626_miles.pdf
# 2020_02_29_230123_2372_miles.pdf
# 2020_02_29_247759_754_miles.pdf
# 2020_02_29_376204_1105_miles.pdf
# ...

# %%
import pytesseract
from pytesseract import Output
import pandas as pd
import cv2 


tesseract_exe_path_installation="C:\\Users\\majidmm\\AppData\\Local\\Tesseract-OCR\\tesseract.exe"
pytesseract.pytesseract.tesseract_cmd=tesseract_exe_path_installation

img_cv = cv2.imread(r'C:\Users\majidmm\Documents\AMXL\INPUT_FILES\Screen_Shot_2020_04_22_at_5.11.24_PM.png')
pdf = pytesseract.image_to_pdf_or_hocr(img_cv, extension='pdf')
with open('test.pdf', 'w+b') as f:
    f.write(pdf) # pdf type is bytes by default

# %%
## format 3 re work

# %%
import pytesseract
import cv2 
import os 
# import pillow


# def get_string(img_path):
#     # Read image using opencv
#     img = cv2.imread(img_path)

#     # Extract the file name without the file extension
#     file_name = os.path.basename(img_path).split('.')[0]
#     file_name = file_name.split()[0]

#     # Create a directory for outputs
#     output_path = os.path.join(output_dir, file_name)
#     if not os.path.exists(output_path):
#         os.makedirs(output_path)


img = cv2.imread(r"C:\Users\majidmm\Documents\AMXL\INPUT_FILES\test_file.png")
img = cv2.resize(img, None, fx=1.2, fy=1.2, interpolation=cv2.INTER_CUBIC)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
kernel = np.ones((1, 1), np.uint8)
img = cv2.dilate(img, kernel, iterations=1)
img = cv2.erode(img, kernel, iterations=1)
result = pytesseract.image_to_string(img, lang="eng")
# return result

result
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-36-c60ff6604692> in <module>
#      20
#      21 img = cv2.imread(r"C:\Users\majidmm\Documents\AMXL\INPUT_FILES\test_file.png")
# ---> 22 img = cv2.resize(img, None, fx=1.2, fy=1.2, interpolation=cv2.INTER_CUBIC)
#      23 img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#      24 kernel = np.ones((1, 1), np.uint8)
#
# error: OpenCV(4.2.0) ..\modules\imgproc\src\resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
